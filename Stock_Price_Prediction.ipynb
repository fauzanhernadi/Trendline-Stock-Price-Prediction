# %% [markdown]
# # Stock Price Prediction
# # Code: NVDA

# %%
# !pip install datetime
# Out:
# Collecting datetime
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Collecting zope.interface (from datetime)
#   Downloading zope.interface-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from datetime) (2024.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from zope.interface->datetime) (71.0.4)
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 2.4 MB/s eta 0:00:00
# Downloading zope.interface-7.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (254 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: zope.interface, datetime
# Successfully installed datetime-5.5 zope.interface-7.0.1

# %%
#import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
from datetime import datetime as dt

# %%
# !pip show yfinance
# Out:
# Name: yfinance
# Version: 0.2.41
# Summary: Download market data from Yahoo! Finance API
# Home-page: https://github.com/ranaroussi/yfinance
# Author: Ran Aroussi
# Author-email: ran@aroussi.com
# License: Apache
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: beautifulsoup4, frozendict, html5lib, lxml, multitasking, numpy, pandas, peewee, platformdirs, pytz, requests
# Required-by:

# %%
import yfinance as yf
df = yf.download('NVDA')
print(df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1999-01-22    0.043750    0.048828    0.038802    0.041016    0.037621
# 1999-01-25    0.044271    0.045833    0.041016    0.045313    0.041562
# 1999-01-26    0.045833    0.046745    0.041146    0.041797    0.038337
# 1999-01-27    0.041927    0.042969    0.039583    0.041667    0.038218
# 1999-01-28    0.041667    0.041927    0.041276    0.041536    0.038098
# ...                ...         ...         ...         ...         ...
# 2024-08-19  124.279999  130.000000  123.419998  130.000000  130.000000
# 2024-08-20  128.399994  129.880005  125.889999  127.250000  127.250000
# 2024-08-21  127.320000  129.350006  126.660004  128.500000  128.500000
# 2024-08-22  130.020004  130.750000  123.099998  123.739998  123.739998
# 2024-08-23  125.870003  129.600006  125.220001  128.139999  128.139999
#
#                 Volume
# Date
# 1999-01-22  2714688000
# 1999-01-25   510480000
# 1999-01-26   343200000
# 1999-01-27   244368000
# 1999-01-28   227520000
# ...                ...
# 2024-08-19   318333600
# 2024-08-20   300087400
# 2024-08-21   257883600
# 2024-08-22   375233400
# 2024-08-23   115324746
#
# [6439 rows x 6 columns]

# %%
df.to_csv('NVDA.csv')

# %%
df = pd.read_csv('NVDA.csv')
df.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1999-01-22  0.043750  0.048828  0.038802  0.041016   0.037621  2714688000
# 1  1999-01-25  0.044271  0.045833  0.041016  0.045313   0.041562   510480000
# 2  1999-01-26  0.045833  0.046745  0.041146  0.041797   0.038337   343200000
# 3  1999-01-27  0.041927  0.042969  0.039583  0.041667   0.038218   244368000
# 4  1999-01-28  0.041667  0.041927  0.041276  0.041536   0.038098   227520000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Low'].plot(kind='hist', bins=20, title='Low')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_4.groupby('Date').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='index', y='Open', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='High', y='Low', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8.plot(kind='scatter', x='Low', y='Close', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Open']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Open')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['High']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('High')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Low']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Low')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Close']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_12.sort_values('index', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('Date')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='Date', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Close')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_13['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Open'].plot(kind='line', figsize=(8, 4), title='Open')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['High'].plot(kind='line', figsize=(8, 4), title='High')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['Low'].plot(kind='line', figsize=(8, 4), title='Low')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='index', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='Open', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='High', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_20['Date'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_20, x='Low', y='Date', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df = df[['Date', 'Close']]
df
# Out:
#             Date       Close
# 0     1999-01-22    0.041016
# 1     1999-01-25    0.045313
# 2     1999-01-26    0.041797
# 3     1999-01-27    0.041667
# 4     1999-01-28    0.041536
# ...          ...         ...
# 6434  2024-08-19  130.000000
# 6435  2024-08-20  127.250000
# 6436  2024-08-21  128.500000
# 6437  2024-08-22  123.739998
# 6438  2024-08-23  128.139999
#
# [6439 rows x 2 columns]

# %%
df['Date']
# Out:
# 0       1999-01-22
# 1       1999-01-25
# 2       1999-01-26
# 3       1999-01-27
# 4       1999-01-28
#            ...
# 6434    2024-08-19
# 6435    2024-08-20
# 6436    2024-08-21
# 6437    2024-08-22
# 6438    2024-08-23
# Name: Date, Length: 6439, dtype: object

# %%
import datetime as dt
def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return dt.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1999-01-22')
datetime_object
# Out:
# datetime.datetime(1999, 1, 22, 0, 0)

# %%
df
# Out:
#             Date       Close
# 0     1999-01-22    0.041016
# 1     1999-01-25    0.045313
# 2     1999-01-26    0.041797
# 3     1999-01-27    0.041667
# 4     1999-01-28    0.041536
# ...          ...         ...
# 6434  2024-08-19  130.000000
# 6435  2024-08-20  127.250000
# 6436  2024-08-21  128.500000
# 6437  2024-08-22  123.739998
# 6438  2024-08-23  128.139999
#
# [6439 rows x 2 columns]

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']
# Out:
# 0      1999-01-22
# 1      1999-01-25
# 2      1999-01-26
# 3      1999-01-27
# 4      1999-01-28
#           ...
# 6434   2024-08-19
# 6435   2024-08-20
# 6436   2024-08-21
# 6437   2024-08-22
# 6438   2024-08-23
# Name: Date, Length: 6439, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 1999-01-22    0.041016
# 1999-01-25    0.045313
# 1999-01-26    0.041797
# 1999-01-27    0.041667
# 1999-01-28    0.041536
# ...                ...
# 2024-08-19  130.000000
# 2024-08-20  127.250000
# 2024-08-21  128.500000
# 2024-08-22  123.739998
# 2024-08-23  128.139999
#
# [6439 rows x 1 columns]

# %%
plt.plot(df.index, df['Close'])

# %%
import datetime
def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date

    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df,
                                '2023-08-21',
                                '2024-08-23',
                                n=3)
windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2023-08-21   43.486000   43.344002   43.299000   46.966999
# 1    2023-08-22   43.344002   43.299000   46.966999   45.667999
# 2    2023-08-23   43.299000   46.966999   45.667999   47.116001
# 3    2023-08-24   46.966999   45.667999   47.116001   47.162998
# 4    2023-08-25   45.667999   47.116001   47.162998   46.018002
# ..          ...         ...         ...         ...         ...
# 250  2024-08-19  118.080002  122.860001  124.580002  130.000000
# 251  2024-08-20  122.860001  124.580002  130.000000  127.250000
# 252  2024-08-21  124.580002  130.000000  127.250000  128.500000
# 253  2024-08-22  130.000000  127.250000  128.500000  123.739998
# 254  2024-08-23  127.250000  128.500000  123.739998  128.139999
#
# [255 rows x 5 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((255,), (255, 3, 1), (255,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_90], X[:q_90], y[:q_90]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(64),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(32, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 5970.2793 - mean_absolute_error: 71.8558 - val_loss: 15978.5547 - val_mean_absolute_error: 126.3311
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5992.0483 - mean_absolute_error: 72.0098 - val_loss: 15829.3584 - val_mean_absolute_error: 125.7392
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5539.3613 - mean_absolute_error: 68.7161 - val_loss: 15622.5186 - val_mean_absolute_error: 124.9140
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5881.9731 - mean_absolute_error: 71.3362 - val_loss: 15335.4990 - val_mean_absolute_error: 123.7597
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5448.9707 - mean_absolute_error: 68.1077 - val_loss: 14931.5615 - val_mean_absolute_error: 122.1168
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5600.8379 - mean_absolute_error: 68.8486 - val_loss: 14375.0576 - val_mean_absolute_error: 119.8165
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5112.5864 - mean_absolute_error: 65.1743 - val_loss: 13600.0410 - val_mean_absolute_error: 116.5373
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4316.9536 - mean_absolute_error: 59.1198 - val_loss: 12510.2891 - val_mean_absolute_error: 111.7636
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3627.3777 - mean_absolute_error: 53.2393 - val_loss: 11068.4023 - val_mean_absolute_error: 105.1141
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3043.8479 - mean_absolute_error: 46.9543 - val_loss: 9060.8965 - val_mean_absolute_error: 95.0869
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2084.6689 - mean_absolute_error: 35.8711 - val_loss: 6948.6948 - val_mean_absolute_error: 83.2425
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1515.0935 - mean_absolute_error: 27.9114 - val_loss: 5202.3306 - val_mean_absolute_error: 71.9944
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1067.5120 - mean_absolute_error: 25.6602 - val_loss: 3830.8977 - val_mean_absolute_error: 61.7387
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 867.5310 - mean_absolute_error: 25.1380 - val_loss: 2936.2881 - val_mean_absolute_error: 54.0111
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 861.1822 - mean_absolute_error: 25.6250 - val_loss: 2641.4873 - val_mean_absolute_error: 51.2102
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 803.6121 - mean_absolute_error: 24.7941 - val_loss: 2584.9673 - val_mean_absolute_error: 50.6558
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 793.0542 - mean_absolute_error: 24.6579 - val_loss: 2758.4287 - val_mean_absolute_error: 52.3408
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 746.5475 - mean_absolute_error: 24.2093 - val_loss: 2907.7009 - val_mean_absolute_error: 53.7481
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 743.3439 - mean_absolute_error: 23.8005 - val_loss: 2940.2932 - val_mean_absolute_error: 54.0525
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 719.7686 - mean_absolute_error: 22.7528 - val_loss: 2694.5735 - val_mean_absolute_error: 51.7297
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 540.9209 - mean_absolute_error: 19.5804 - val_loss: 2281.4009 - val_mean_absolute_error: 47.5702
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 433.0445 - mean_absolute_error: 15.7477 - val_loss: 1770.6033 - val_mean_absolute_error: 41.8610
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 230.0622 - mean_absolute_error: 8.7782 - val_loss: 1176.1018 - val_mean_absolute_error: 34.0224
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 129.7400 - mean_absolute_error: 5.9734 - val_loss: 770.6880 - val_mean_absolute_error: 27.4305
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 99.8840 - mean_absolute_error: 5.2420 - val_loss: 477.0728 - val_mean_absolute_error: 21.4253
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 58.5236 - mean_absolute_error: 4.1896 - val_loss: 304.7686 - val_mean_absolute_error: 16.9467
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 30.1377 - mean_absolute_error: 3.0679 - val_loss: 181.1074 - val_mean_absolute_error: 12.7859
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 27.3450 - mean_absolute_error: 2.9810 - val_loss: 102.0726 - val_mean_absolute_error: 9.1906
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 16.2637 - mean_absolute_error: 2.6987 - val_loss: 66.0905 - val_mean_absolute_error: 7.3467
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9784 - mean_absolute_error: 2.2698 - val_loss: 43.2907 - val_mean_absolute_error: 5.8007
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2918 - mean_absolute_error: 1.9626 - val_loss: 31.4058 - val_mean_absolute_error: 4.7288
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2490 - mean_absolute_error: 1.9687 - val_loss: 26.3284 - val_mean_absolute_error: 4.2449
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4505 - mean_absolute_error: 1.8711 - val_loss: 23.4960 - val_mean_absolute_error: 3.9461
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6688 - mean_absolute_error: 2.0282 - val_loss: 20.8774 - val_mean_absolute_error: 3.6501
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5354 - mean_absolute_error: 1.9181 - val_loss: 19.3196 - val_mean_absolute_error: 3.4555
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9140 - mean_absolute_error: 1.8420 - val_loss: 16.7250 - val_mean_absolute_error: 3.1778
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3869 - mean_absolute_error: 2.0496 - val_loss: 18.2395 - val_mean_absolute_error: 3.3026
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6549 - mean_absolute_error: 1.9153 - val_loss: 17.3263 - val_mean_absolute_error: 3.2225
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9755 - mean_absolute_error: 1.7403 - val_loss: 16.7521 - val_mean_absolute_error: 3.1938
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7096 - mean_absolute_error: 1.6215 - val_loss: 15.8667 - val_mean_absolute_error: 3.1420
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5759 - mean_absolute_error: 1.7358 - val_loss: 15.5698 - val_mean_absolute_error: 3.1161
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8097 - mean_absolute_error: 1.8507 - val_loss: 15.3604 - val_mean_absolute_error: 3.0759
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8236 - mean_absolute_error: 1.9488 - val_loss: 15.2344 - val_mean_absolute_error: 3.0663
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 10.4543 - mean_absolute_error: 2.5710 - val_loss: 17.5532 - val_mean_absolute_error: 3.2837
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8162 - mean_absolute_error: 2.1391 - val_loss: 15.4460 - val_mean_absolute_error: 3.1152
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8641 - mean_absolute_error: 1.8015 - val_loss: 15.3002 - val_mean_absolute_error: 3.1015
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3801 - mean_absolute_error: 1.7898 - val_loss: 18.2411 - val_mean_absolute_error: 3.3824
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2183 - mean_absolute_error: 1.6091 - val_loss: 15.6739 - val_mean_absolute_error: 3.1397
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9198 - mean_absolute_error: 1.8265 - val_loss: 15.1234 - val_mean_absolute_error: 3.0850
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3833 - mean_absolute_error: 1.6240 - val_loss: 16.7273 - val_mean_absolute_error: 3.2371
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0137 - mean_absolute_error: 1.8738 - val_loss: 15.8772 - val_mean_absolute_error: 3.0725
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7253 - mean_absolute_error: 2.0714 - val_loss: 16.5646 - val_mean_absolute_error: 3.2175
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6510 - mean_absolute_error: 1.8378 - val_loss: 15.0010 - val_mean_absolute_error: 3.0449
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1608 - mean_absolute_error: 1.9673 - val_loss: 14.9357 - val_mean_absolute_error: 3.0443
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5715 - mean_absolute_error: 1.7782 - val_loss: 14.9431 - val_mean_absolute_error: 3.0533
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4239 - mean_absolute_error: 1.5988 - val_loss: 15.0670 - val_mean_absolute_error: 3.0669
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4705 - mean_absolute_error: 2.1522 - val_loss: 16.3272 - val_mean_absolute_error: 3.2306
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1025 - mean_absolute_error: 1.7481 - val_loss: 15.1938 - val_mean_absolute_error: 3.0259
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4494 - mean_absolute_error: 1.8241 - val_loss: 18.3973 - val_mean_absolute_error: 3.4304
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0327 - mean_absolute_error: 1.7592 - val_loss: 14.9072 - val_mean_absolute_error: 3.0537
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7302 - mean_absolute_error: 1.6769 - val_loss: 14.9249 - val_mean_absolute_error: 3.0475
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4661 - mean_absolute_error: 1.6764 - val_loss: 16.1941 - val_mean_absolute_error: 3.1967
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6754 - mean_absolute_error: 1.8788 - val_loss: 14.8979 - val_mean_absolute_error: 3.0577
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8082 - mean_absolute_error: 1.7177 - val_loss: 15.2152 - val_mean_absolute_error: 3.0249
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1836 - mean_absolute_error: 1.8377 - val_loss: 15.3664 - val_mean_absolute_error: 3.1045
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6699 - mean_absolute_error: 1.7698 - val_loss: 15.4937 - val_mean_absolute_error: 3.1141
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0813 - mean_absolute_error: 1.8872 - val_loss: 14.8065 - val_mean_absolute_error: 3.0387
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4862 - mean_absolute_error: 1.6695 - val_loss: 15.1672 - val_mean_absolute_error: 3.0876
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8845 - mean_absolute_error: 1.6898 - val_loss: 14.9941 - val_mean_absolute_error: 3.0708
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5701 - mean_absolute_error: 1.6483 - val_loss: 14.8490 - val_mean_absolute_error: 3.0107
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0128 - mean_absolute_error: 1.7705 - val_loss: 17.1323 - val_mean_absolute_error: 3.3103
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3281 - mean_absolute_error: 2.1277 - val_loss: 17.9903 - val_mean_absolute_error: 3.3898
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6950 - mean_absolute_error: 1.9878 - val_loss: 14.9152 - val_mean_absolute_error: 3.0025
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5807 - mean_absolute_error: 1.7490 - val_loss: 15.7558 - val_mean_absolute_error: 3.1541
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2249 - mean_absolute_error: 1.8246 - val_loss: 14.9980 - val_mean_absolute_error: 3.0621
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4335 - mean_absolute_error: 1.6039 - val_loss: 15.5543 - val_mean_absolute_error: 3.1281
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.2736 - mean_absolute_error: 1.7940 - val_loss: 15.1231 - val_mean_absolute_error: 3.0805
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0106 - mean_absolute_error: 1.6038 - val_loss: 16.7928 - val_mean_absolute_error: 3.2830
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.5589 - mean_absolute_error: 1.7560 - val_loss: 14.7876 - val_mean_absolute_error: 3.0192
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2374 - mean_absolute_error: 1.5974 - val_loss: 15.5216 - val_mean_absolute_error: 3.1148
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2129 - mean_absolute_error: 2.0170 - val_loss: 22.5179 - val_mean_absolute_error: 3.8956
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7950 - mean_absolute_error: 1.7453 - val_loss: 14.7879 - val_mean_absolute_error: 3.0053
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0692 - mean_absolute_error: 1.6362 - val_loss: 17.0719 - val_mean_absolute_error: 3.3068
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7427 - mean_absolute_error: 1.8587 - val_loss: 15.6757 - val_mean_absolute_error: 3.1415
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7773 - mean_absolute_error: 1.8649 - val_loss: 15.1786 - val_mean_absolute_error: 3.0773
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.8812 - mean_absolute_error: 1.7260 - val_loss: 14.7919 - val_mean_absolute_error: 3.0046
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.3984 - mean_absolute_error: 1.8345 - val_loss: 14.7369 - val_mean_absolute_error: 3.0099
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.7947 - mean_absolute_error: 1.8371 - val_loss: 15.2185 - val_mean_absolute_error: 3.0846
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.6388 - mean_absolute_error: 1.8233 - val_loss: 15.0792 - val_mean_absolute_error: 3.0665
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 6.8232 - mean_absolute_error: 1.8097 - val_loss: 14.7179 - val_mean_absolute_error: 3.0183
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8231 - mean_absolute_error: 1.6700 - val_loss: 15.6102 - val_mean_absolute_error: 3.1457
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6220 - mean_absolute_error: 1.7449 - val_loss: 14.7527 - val_mean_absolute_error: 3.0189
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1448 - mean_absolute_error: 1.6946 - val_loss: 15.1975 - val_mean_absolute_error: 3.0855
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5839 - mean_absolute_error: 1.6398 - val_loss: 15.0667 - val_mean_absolute_error: 3.0657
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7600 - mean_absolute_error: 1.7577 - val_loss: 16.1478 - val_mean_absolute_error: 3.2159
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8685 - mean_absolute_error: 1.8108 - val_loss: 14.7276 - val_mean_absolute_error: 3.0257
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4262 - mean_absolute_error: 1.8475 - val_loss: 14.9773 - val_mean_absolute_error: 3.0638
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6616 - mean_absolute_error: 1.8796 - val_loss: 15.1276 - val_mean_absolute_error: 3.0778
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0759 - mean_absolute_error: 1.8575 - val_loss: 14.9979 - val_mean_absolute_error: 3.0625
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5399 - mean_absolute_error: 1.6628 - val_loss: 14.6405 - val_mean_absolute_error: 2.9975

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
val_predictions = model.predict(X_val).flatten()
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
